# %%
import re
email="#$$$@!yalpstcejorp EPUVT****9887"
clean_email=re.sub(r'[\W\d]'," ",email)
clean_email.strip()


#test
# Out:
# 'yalpstcejorp EPUVT'

# %%
first_word=clean_email.split()[0]
correct_word=first_word[::-1]
correct_word
# Out:
# 'projectsplay'

# %%
second_word=clean_email.split()[1]
replca_char=second_word.replace("E","A").replace("U","O")
replca_char
# Out:
# 'APOVT'

# %%
print(f"Final decoded message: {correct_word} {replca_char}")
# Out:
# Final decoded message: projectsplay APOVT
