# %%
list_one=["depi","learing","python"]
list_one.append("ml")
list_one
# Out:
# ['depi', 'learing', 'python', 'ml']

# %%
list_one=["depi","learing","python"]
list_one.insert(1,"Data analysis")
list_one
#ipfjond
# Out:
# ['depi', 'Data analysis', 'learing', 'python']
