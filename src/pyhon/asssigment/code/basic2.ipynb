# %%
list_one=["depi","learing","python"]
list_one.append("ml")
list_one
# Out:
# ['depi', 'learing', 'python', 'ml']

# %%
list_one=["depi","learing","python"]
list_one.insert(1,"Data analysis")
list_one
#ipfjond
# Out:
# ['depi', 'Data analysis', 'learing', 'python']

# %%
list_one = ["depi", "learning", "python"]
list_one.remove("depi")
list_one
# Out:
# ['learning', 'python']

# %%
list_one = ["depi", "learning", "python"]
x = list_one.pop()
print(list_one)
print(x)
# Out:
# ['depi', 'learning']
# python

# %%
list_1 = ["Depi", "nti", "iti"]
new_list = []

task_1 = list_1.pop()
new_list.append(task_1)

print(list_1)
print(new_list)
# Out:
# ['Depi', 'nti']
# ['iti']

# %%
list_one = ["depi", "learning", "python"]
del list_one[:]
list_one
#فس
# Out:
# []

# %%
list_1=[1,2,3,4]
index_val=list_1.index(3)
index_val
# Out:
# 2

# %%
list_1=[1,2,3,3,3,4]
index_val=list_1.count(3)
index_val
# Out:
# 3

# %%
list_1=[200,100,500,900,300]
list_1.sort(reverse=True)
list_1
# Out:
# [900, 500, 300, 200, 100]

# %%
list_1=[200,100,500,900,300]
list_1.reverse()
list_1
# Out:
# [300, 900, 500, 100, 200]

# %%
tuple_1=("depi","learing","python")
tuple_1[1]="mazen"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 tuple_1=("depi","learing","python")
# ----> 2 tuple_1[1]="mazen"
#
# TypeError: 'tuple' object does not support item assignment

# %%
tuple_1=("depi","learing","python")
list_1=list(tuple_1)
list_1.append("php") 
list_1
# Out:
# ['depi', 'learing', 'python', 'php']

# %%
print(dir(tuple))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'count', 'index']

# %%
print(dir(set))
# Out:
# ['__and__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__ixor__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__ror__', '__rsub__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__xor__', 'add', 'clear', 'copy', 'difference', 'difference_update', 'discard', 'intersection', 'intersection_update', 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove', 'symmetric_difference', 'symmetric_difference_update', 'union', 'update']

# %%
set_one={"depi","learing"}
list(set_one)
# Out:
# ['depi', 'learing']

# %%
set_one={"depi","learing"}
set_one.add("python")
set_one
# Out:
# {'depi', 'learing', 'python'}

# %%
set_one={"depi","learing"}
set_one.remove("depi")
set_one
# Out:
# {'learing'}

# %%
data1={
    101,
    102,
    103,
    104,
}

data2={
    103,
    104,
    105,
    106,
}
print(data1.intersection(data2))
# Out:
# {104, 103}

# %%
print(data1.union(data2))
# Out:
# {101, 102, 103, 104, 105, 106}

# %%
dict_1={"k1":100,
        "k2":200,
        4:[1,2,3]
        }
type(dict_1)
# Out:
# dict

# %%
dict_1["k1"]="python"
dict_1
# Out:
# {'k1': 'python', 'k2': 200, 4: [1, 2, 3]}

# %%
dict_1[4][0]
# Out:
# 1

# %%
chatbot = {
    "hello" : "hello how can i help you",
    "python": "python is a programming language",
    "ai"    : "enable machine learning to learn fro data"
}
print(chatbot.keys())
# Out:
# dict_keys(['hello', 'python', 'ai'])

# %%
question=input("quesition: ").lower()
print(chatbot.get(question,"your answer not found "))
# Out:
# hello how can i help you
