# %%
def show_balance():
    print(f"balance : ${balance:.2f}")

def Deposit():
    amount=int(input("Deposit money: "))

    if amount<0:
        print("Wrong please Deposit money first ")
        return 0
    else:
        return amount

def Withdraw():
    amount=int(input("enter Withdraw : "))

    if amount>balance:
        print("Insufficient funds! The amount exceeds your current balance.")
        return 0
    elif amount<0:
        print("Invalid amount! Please enter a positive number.")
        return 0
    else:
        return amount

balance=0
running_programming=True

while running_programming:
    option=input("chose between (1 to 4 ): ")
    print("Banking programming")
    print("-"*30)
    print("1- show balance")
    print("2- Deposit")
    print("3- Withdraw")
    print("4- quit")

    if option=="1":
        show_balance()
    elif option=="2":
        balance+=Deposit()
    elif option=="3":
        balance-=Withdraw()
    elif option=="4":
        print("system is shutdown ")
        running_programming=False
# Out:
# Banking programming
# ------------------------------
# 1- show balance
# 2- Deposit
# 3- Withdraw
# 4- quit
# Banking programming
# ------------------------------
# 1- show balance
# 2- Deposit
# 3- Withdraw
# 4- quit
# Banking programming
# ------------------------------
# 1- show balance
# 2- Deposit
# 3- Withdraw
# 4- quit
# Banking programming
# ------------------------------
# 1- show balance
# 2- Deposit
# 3- Withdraw
# 4- quit
# Banking programming
# ------------------------------
# 1- show balance
# 2- Deposit
# 3- Withdraw
# 4- quit
# Banking programming
# ------------------------------
# 1- show balance
# 2- Deposit
# 3- Withdraw
# 4- quit
# system is shutdown
